# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from hyperparam_scan_util import GridScanExports

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load

# %%
exports = GridScanExports.load("exports/grid_scans/main_v3.2_test")
trials_df = exports.trials
epochs_df = exports.epochs
exports
# Out:
# GridScanExports(52 runs, 220 trials, 10761 epochs)

# %%
trials_df.head()
# Out:
#             scan_id      run_id                  started_at  \
# 182  main_v3.2_test  17056121_4  2024-09-27_15-40-28_952775
# 105  main_v3.2_test  17056121_3  2024-09-27_15-40-29_007346
# 19   main_v3.2_test  17056121_1  2024-09-27_15-40-29_016731
# 145  main_v3.2_test  17056121_2  2024-09-27_15-40-29_018275
# 30   main_v3.2_test  17056121_6  2024-09-27_15-40-30_031064
#
#                     finished_at    duration error  \
# 182  2024-09-27_15-43-38_333886  189.381111  None
# 105  2024-09-27_15-43-34_057264  185.049918  None
# 19   2024-09-27_15-43-31_446471  182.429740  None
# 145  2024-09-27_15-43-47_576960  198.558685  None
# 30   2024-09-27_15-43-50_116238  200.085174  None
#
#                           config_hash  config.device_count  config.seed  \
# 182  2bb3941bcc4366c8cde7f979b5a23373                    1            0
# 105  4b2566b4d0cfbff32e1090a357d24e95                    1            0
# 19   4d3626d273face885d39b677afc9be82                    1            0
# 145  6b0278924afe2ddfa6572d85fe9fc421                    1            0
# 30   8f42b8860d20152e12e533895b91968e                    1            0
#
#      config.I0  config.eps  config.Nhidden  config.Nlayer  config.Nout  \
# 182       1.25    0.000001             128              2           20
# 105       1.25    0.000001             128              2           20
# 19        1.25    0.000001             128              2           20
# 145       1.25    0.000001             128              3           20
# 30        1.25    0.000001             128              3           20
#
#      config.w_scale  config.K  config.dt  config.gamma  config.Nbatch  \
# 182             0.5       700      0.001         0.100           1000
# 105             0.5       700      0.001         0.010           1000
# 19              0.5       700      0.001         0.001           1000
# 145             0.5       700      0.001         0.001           1000
# 30              0.5       700      0.001         0.100           1000
#
#      config.lr  config.tau_lr  config.beta1  config.beta2  config.p_flip  \
# 182      0.004          100.0           0.9         0.999            0.0
# 105      0.004          100.0           0.9         0.999            0.0
# 19       0.004          100.0           0.9         0.999            0.0
# 145      0.004          100.0           0.9         0.999            0.0
# 30       0.004          100.0           0.9         0.999            0.0
#
#      config.Nepochs config.Ntrain  config.Nin  config.Nsamples  \
# 182              50          None         700                3
# 105              50          None         700                3
# 19               50          None         700                3
# 145              50          None         700                3
# 30               50          None         700                3
#
#      config.normalize_times  config.tau  config.T  metrics.acc_init_mean  \
# 182                    True         1.0       2.0               0.048795
# 105                    True         1.0       2.0               0.048795
# 19                     True         1.0       2.0               0.048795
# 145                    True         1.0       2.0               0.050057
# 30                     True         1.0       2.0               0.050057
#
#      metrics.acc_init_std  metrics.acc_final_mean  metrics.acc_final_std  \
# 182              0.003352                0.063815               0.016493
# 105              0.003352                0.235515               0.006842
# 19               0.003352                0.234785               0.008502
# 145              0.001500                0.229606               0.002149
# 30               0.001500                0.050040               0.005196
#
#      metrics.acc_min_epoch  metrics.acc_min_mean  metrics.acc_min_std  \
# 182                   46.0              0.047842             0.004008
# 105                    0.0              0.048795             0.003352
# 19                     0.0              0.048795             0.003352
# 145                    0.0              0.050057             0.001500
# 30                     6.0              0.047111             0.002529
#
#      metrics.acc_max_epoch  metrics.acc_max_mean  metrics.acc_max_std  \
# 182                   34.0              0.071539             0.014792
# 105                   22.0              0.237700             0.019440
# 19                    47.0              0.239680             0.014019
# 145                   46.0              0.234609             0.004606
# 30                    21.0              0.055926             0.005751
#
#      metrics.acc_ord_init_mean  metrics.acc_ord_init_std  \
# 182                   0.045795                  0.001579
# 105                   0.045795                  0.001579
# 19                    0.045795                  0.001579
# 145                   0.045795                  0.001579
# 30                    0.045795                  0.001579
#
#      metrics.acc_ord_final_mean  metrics.acc_ord_final_std  \
# 182                    0.044865                   0.001159
# 105                    0.044865                   0.001159
# 19                     0.044865                   0.001159
# 145                    0.044865                   0.001159
# 30                     0.044865                   0.001159
#
#      metrics.acc_ord_min_epoch  metrics.acc_ord_min_mean  \
# 182                       19.0                  0.042387
# 105                       19.0                  0.042387
# 19                        19.0                  0.042387
# 145                       19.0                  0.042387
# 30                        19.0                  0.042387
#
#      metrics.acc_ord_min_std  metrics.acc_ord_max_epoch  \
# 182                 0.000876                        5.0
# 105                 0.000876                        5.0
# 19                  0.000876                        5.0
# 145                 0.000876                        5.0
# 30                  0.000876                        5.0
#
#      metrics.acc_ord_max_mean  metrics.acc_ord_max_std  \
# 182                  0.049202                 0.003477
# 105                  0.049202                 0.003477
# 19                   0.049202                 0.003477
# 145                  0.049202                 0.003477
# 30                   0.049202                 0.003477
#
#      metrics.activity_init_mean  metrics.activity_init_std  \
# 182                1.736111e-06                   0.000002
# 105                1.736111e-06                   0.000002
# 19                 1.736111e-06                   0.000002
# 145                8.680556e-07                   0.000001
# 30                 8.680556e-07                   0.000001
#
#      metrics.activity_final_mean  metrics.activity_final_std  \
# 182                 1.736111e-06                    0.000002
# 105                 1.736111e-06                    0.000002
# 19                  1.736111e-06                    0.000002
# 145                 8.680556e-07                    0.000001
# 30                  8.680556e-07                    0.000001
#
#      metrics.activity_min_epoch  metrics.activity_min_mean  \
# 182                         0.0               1.736111e-06
# 105                         0.0               1.736111e-06
# 19                          0.0               1.736111e-06
# 145                         0.0               8.680556e-07
# 30                          0.0               8.680556e-07
#
#      metrics.activity_min_std  metrics.activity_max_epoch  \
# 182                  0.000002                         0.0
# 105                  0.000002                         0.0
# 19                   0.000002                         0.0
# 145                  0.000001                         0.0
# 30                   0.000001                         0.0
#
#      metrics.activity_max_mean  metrics.activity_max_std  \
# 182               1.736111e-06                  0.000002
# 105               1.736111e-06                  0.000002
# 19                1.736111e-06                  0.000002
# 145               8.680556e-07                  0.000001
# 30                8.680556e-07                  0.000001
#
#      metrics.activity_first_init_mean  metrics.activity_first_init_std  \
# 182                               0.0                              0.0
# 105                               0.0                              0.0
# 19                                0.0                              0.0
# 145                               0.0                              0.0
# 30                                0.0                              0.0
#
#      metrics.activity_first_final_mean  metrics.activity_first_final_std  \
# 182                                0.0                               0.0
# 105                                0.0                               0.0
# 19                                 0.0                               0.0
# 145                                0.0                               0.0
# 30                                 0.0                               0.0
#
#      metrics.activity_first_min_epoch  metrics.activity_first_min_mean  \
# 182                               0.0                              0.0
# 105                               0.0                              0.0
# 19                                0.0                              0.0
# 145                               0.0                              0.0
# 30                                0.0                              0.0
#
#      metrics.activity_first_min_std  metrics.activity_first_max_epoch  \
# 182                             0.0                               0.0
# 105                             0.0                               0.0
# 19                              0.0                               0.0
# 145                             0.0                               0.0
# 30                              0.0                               0.0
#
#      metrics.activity_first_max_mean  metrics.activity_first_max_std  \
# 182                              0.0                             0.0
# 105                              0.0                             0.0
# 19                               0.0                             0.0
# 145                              0.0                             0.0
# 30                               0.0                             0.0
#
#      metrics.epoch_time_mean  metrics.epoch_time_std  \
# 182                 1.162390                0.029608
# 105                 1.134142                0.043052
# 19                  1.116225                0.021044
# 145                 1.214669                0.038726
# 30                  1.224061                0.060579
#
#      metrics.init_compile_time_mean  metrics.init_compile_time_std  \
# 182                        0.000575                       0.000041
# 105                        0.000614                       0.000009
# 19                         0.000586                       0.000023
# 145                        0.000587                       0.000032
# 30                         0.000622                       0.000103
#
#      metrics.init_optim_time_mean  metrics.init_optim_time_std  \
# 182                      0.015516                     0.018792
# 105                      0.015244                     0.018347
# 19                       0.015466                     0.018666
# 145                      0.023309                     0.029022
# 30                       0.021790                     0.026885
#
#      metrics.init_phi0_time_mean  metrics.init_phi0_time_std  \
# 182                     0.023999                    0.032982
# 105                     0.025373                    0.034895
# 19                      0.024070                    0.033102
# 145                     0.024867                    0.033982
# 30                      0.022825                    0.031091
#
#      metrics.init_time_mean  metrics.init_time_std  \
# 182                3.572277               1.271908
# 105                3.542635               1.258246
# 19                 3.563269               1.281256
# 145                4.003704               1.656307
# 30                 4.048947               1.715285
#
#      metrics.init_weights_time_mean  metrics.init_weights_time_std  \
# 182                        0.165017                       0.231783
# 105                        0.169011                       0.237313
# 19                         0.165884                       0.233002
# 145                        0.219442                       0.308334
# 30                         0.209240                       0.293872
#
#      metrics.loss_init_mean  metrics.loss_init_std  metrics.loss_final_mean  \
# 182                3.457599               0.003967                 3.060941
# 105                3.053710               0.004558                 2.602609
# 19                 3.013321               0.004855                 2.570562
# 145                3.012034               0.004450                 2.391784
# 30                 3.467347               0.011440                 3.176239
#
#      metrics.loss_final_std  metrics.loss_min_epoch  metrics.loss_min_mean  \
# 182                0.062875                    50.0               3.060941
# 105                0.008294                    50.0               2.602609
# 19                 0.008143                    50.0               2.570562
# 145                0.014285                    50.0               2.391784
# 30                 0.000389                    50.0               3.176239
#
#      metrics.loss_min_std  metrics.loss_max_epoch  metrics.loss_max_mean  \
# 182              0.062875                     0.0               3.457599
# 105              0.008294                     0.0               3.053710
# 19               0.008143                     0.0               3.013321
# 145              0.014285                     0.0               3.012034
# 30               0.000389                     0.0               3.467347
#
#      metrics.loss_max_std  metrics.loss_ord_init_mean  \
# 182              0.003967                    3.167561
# 105              0.004558                    3.012916
# 19               0.004855                    2.997451
# 145              0.004450                    2.997451
# 30               0.011440                    3.167561
#
#      metrics.loss_ord_init_std  metrics.loss_ord_final_mean  \
# 182               2.384186e-07                     3.167561
# 105               0.000000e+00                     3.012916
# 19                0.000000e+00                     2.997451
# 145               0.000000e+00                     2.997451
# 30                2.384186e-07                     3.167561
#
#      metrics.loss_ord_final_std  metrics.loss_ord_min_epoch  \
# 182                2.384186e-07                         0.0
# 105                0.000000e+00                         0.0
# 19                 0.000000e+00                         0.0
# 145                0.000000e+00                         0.0
# 30                 2.384186e-07                         0.0
#
#      metrics.loss_ord_min_mean  metrics.loss_ord_min_std  \
# 182                   3.167561              2.384186e-07
# 105                   3.012916              0.000000e+00
# 19                    2.997451              0.000000e+00
# 145                   2.997451              0.000000e+00
# 30                    3.167561              2.384186e-07
#
#      metrics.loss_ord_max_epoch  metrics.loss_ord_max_mean  \
# 182                         0.0                   3.167561
# 105                         0.0                   3.012916
# 19                          0.0                   2.997451
# 145                         0.0                   2.997451
# 30                          0.0                   3.167561
#
#      metrics.loss_ord_max_std  metrics.silent_neurons_init_mean  \
# 182              2.384186e-07                          0.997396
# 105              0.000000e+00                          0.997396
# 19               0.000000e+00                          0.997396
# 145              0.000000e+00                          0.998698
# 30               2.384186e-07                          0.998698
#
#      metrics.silent_neurons_init_std  metrics.silent_neurons_final_mean  \
# 182                         0.003683                           0.997396
# 105                         0.003683                           0.997396
# 19                          0.003683                           0.997396
# 145                         0.001841                           0.998698
# 30                          0.001841                           0.998698
#
#      metrics.silent_neurons_final_std  metrics.silent_neurons_min_epoch  \
# 182                          0.003683                               0.0
# 105                          0.003683                               0.0
# 19                           0.003683                               0.0
# 145                          0.001841                               0.0
# 30                           0.001841                               0.0
#
#      metrics.silent_neurons_min_mean  metrics.silent_neurons_min_std  \
# 182                         0.997396                        0.003683
# 105                         0.997396                        0.003683
# 19                          0.997396                        0.003683
# 145                         0.998698                        0.001841
# 30                          0.998698                        0.001841
#
#      metrics.silent_neurons_max_epoch  metrics.silent_neurons_max_mean  \
# 182                               0.0                         0.997396
# 105                               0.0                         0.997396
# 19                                0.0                         0.997396
# 145                               0.0                         0.998698
# 30                                0.0                         0.998698
#
#      metrics.silent_neurons_max_std  metrics.silent_neurons_first_init_mean  \
# 182                        0.003683                                     1.0
# 105                        0.003683                                     1.0
# 19                         0.003683                                     1.0
# 145                        0.001841                                     1.0
# 30                         0.001841                                     1.0
#
#      metrics.silent_neurons_first_init_std  \
# 182                                    0.0
# 105                                    0.0
# 19                                     0.0
# 145                                    0.0
# 30                                     0.0
#
#      metrics.silent_neurons_first_final_mean  \
# 182                                      1.0
# 105                                      1.0
# 19                                       1.0
# 145                                      1.0
# 30                                       1.0
#
#      metrics.silent_neurons_first_final_std  \
# 182                                     0.0
# 105                                     0.0
# 19                                      0.0
# 145                                     0.0
# 30                                      0.0
#
#      metrics.silent_neurons_first_min_epoch  \
# 182                                     0.0
# 105                                     0.0
# 19                                      0.0
# 145                                     0.0
# 30                                      0.0
#
#      metrics.silent_neurons_first_min_mean  \
# 182                                    1.0
# 105                                    1.0
# 19                                     1.0
# 145                                    1.0
# 30                                     1.0
#
#      metrics.silent_neurons_first_min_std  \
# 182                                   0.0
# 105                                   0.0
# 19                                    0.0
# 145                                   0.0
# 30                                    0.0
#
#      metrics.silent_neurons_first_max_epoch  \
# 182                                     0.0
# 105                                     0.0
# 19                                      0.0
# 145                                     0.0
# 30                                      0.0
#
#      metrics.silent_neurons_first_max_mean  \
# 182                                    1.0
# 105                                    1.0
# 19                                     1.0
# 145                                    1.0
# 30                                     1.0
#
#      metrics.silent_neurons_first_max_std  metrics.train_time_mean  \
# 182                                   0.0                58.119507
# 105                                   0.0                56.707108
# 19                                    0.0                55.811256
# 145                                   0.0                60.733421
# 30                                    0.0                61.203030
#
#      metrics.train_time_std
# 182                1.480389
# 105                2.152606
# 19                 1.052193
# 145                1.936296
# 30                 3.028952

# %% [markdown]
# ## Error Summary

# %%
n_error = trials_df["error"].notna().sum()
print(f"{n_error} / {len(trials_df)} trials contain errors")
print()

for i, error in enumerate(trials_df["error"].dropna().sort_values().unique()):
    short_error = str(error).split("---", 1)[0].strip().split("\n")[-1]
    print(short_error)
    trials = trials_df[trials_df["error"] == error]
    print(f"Appears in {len(trials)} trials: {trials['config_hash'].tolist()}")
    print()
# Out:
# 9 / 220 trials contain errors
#
# jaxlib.xla_extension.XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 54061277552 bytes.
# Appears in 6 trials: ['94dd9f4dd7901205fc60b4ee34dc8a93', '1c974bc414cc66eaaa9cfe13c6a97085', '2a35eb92e52ee5150e799f3280dcc2d6', '91b308c82fdafcdc555e674bc60bbdb8', '97d6914aa32e66782ca7a4c889c62264', '275a0ae545aeb49355a59e8e05544bda']
#
# jaxlib.xla_extension.XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 54061973872 bytes.
# Appears in 3 trials: ['09f3ad236102683e7070492bce5bba8a', '4b7f7174870dabc76d8593a9f1d4d624', '6828e062076e3cf734655e92d6383b6a']

# %%
def key_format(key: str):
    return key.removeprefix("config.").removeprefix("metrics.")


indep_keys = tuple(
    key for key in trials_df.columns
    if key.startswith("config.") and key != "config.Nin"
)
print("independent keys:", indep_keys)
# Out:
# independent keys: ('config.device_count', 'config.seed', 'config.I0', 'config.eps', 'config.Nhidden', 'config.Nlayer', 'config.Nout', 'config.w_scale', 'config.K', 'config.dt', 'config.gamma', 'config.Nbatch', 'config.lr', 'config.tau_lr', 'config.beta1', 'config.beta2', 'config.p_flip', 'config.Nepochs', 'config.Ntrain', 'config.Nsamples', 'config.normalize_times', 'config.tau', 'config.T')

# %%
from spikegd.utils.data import Data

trials_data = Data(trials_df, indep_keys)
print(trials_data.schema())
# Out:
# Data:
#   const config.device_count = 1
#   const config.seed = 0
#   const config.I0 = 1.25
#   const config.eps = 1e-06
#   const config.Nhidden = 128
#   const config.Nout = 20
#   const config.w_scale = 0.5
#   const config.dt = 0.001
#   const config.Nbatch = 1000
#   const config.lr = 0.004
#   const config.tau_lr = 100.0
#   const config.beta1 = 0.9
#   const config.beta2 = 0.999
#   const config.p_flip = 0.0
#   const config.Nepochs = 50
#   const config.Ntrain = None
#   const config.Nsamples = 3
#   const config.normalize_times = True
#   var config.Nlayer = 2 (119x), 3 (101x)
#   var config.K = 700 (104x), 2000 (98x), 20000 (9x), 10000 (9x)
#   var config.gamma = 0.01 (216x), 0.1 (2x), 0.001 (2x)
#   var config.tau = 1.0 (40x), 4.0 (34x), 0.0625 (28x), 0.25 (28x), 16.0 (28x), 64.0 (28x), 256.0 (28x), 2.0 (6x)
#   var config.T = 4.0 (34x), 0.0625 (28x), 0.25 (28x), 1.0 (28x), 16.0 (28x), 64.0 (28x), 256.0 (28x), 2.0 (12x), 8.0 (6x)

# %% [markdown]
# ## Dependencies on time constants

# %%
from spikegd.utils.plotting import PlotGrid, LinePlot


PlotGrid(
    arg_keys=("config.T",),
    func_keys=(
        "metrics.acc_max_mean",
        "metrics.acc_ord_max_mean",
        # "metrics.acc_final_mean",
        # "metrics.epoch_time_mean",
        "metrics.acc_max_epoch",
        "metrics.silent_neurons_final_mean",
    ),
    func_aggs={"*": "mean"},
    plots=[LinePlot(
        graph_key="config.gamma",
        x_scale="log",
    )],
    col_keys="config.tau",
    agg_keys=("config.w_scale", "config.K", "config.Nlayer", "config.Nbatch"),
    # fixed_values={"config.K": 700},
    whitelists={"config.tau": [0.1, 0.5, 1, 2]},
    indep_keys=indep_keys,
    key_format=key_format,
).show(trials_df)

# %%
PlotGrid(
    arg_keys=("config.T",),
    func_keys=(
        "metrics.acc_max_mean",
        "metrics.acc_ord_max_mean",
        # "metrics.acc_final_mean",
        # "metrics.epoch_time_mean",
        "metrics.acc_max_epoch",
        "metrics.silent_neurons_final_mean",
    ),
    func_aggs={"*": "mean"},
    plots=[LinePlot(
        graph_key="config.w_scale",
        x_scale="log",
    )],
    col_keys="config.tau",
    agg_keys=("config.w_scale", "config.K", "config.Nlayer", "config.Nbatch"),
    whitelists={"config.tau": [0.1, 0.5, 1, 2]},
    indep_keys=indep_keys,
    key_format=key_format,
).show(trials_df)
# Out:
# Independent key 'config.gamma' has multiple values: [0.01, 0.1, 0.001]. Using most frequent value: 0.01

# %%
from matplotlib.axes import Axes
from pandas.core.api import DataFrame as DataFrame
from spikegd.utils.plotting import HeatmapPlot, Plot, PlotGrid, _get_val_list


class NanXPlot(Plot):
    def __init__(self, key: str):
        self.key = key
    
    def draw_to_ax(
        self,
        grid: PlotGrid,
        full_df: DataFrame,
        ax: Axes,
        ax_df: DataFrame,
        func_key: str,
        func_agg: str | None,
    ) -> None:
        if len(grid.arg_keys) != 2:
            raise ValueError(
                "HeatmapPlot requires exactly two arg keys since it is 2-dimensional"
            )

        x_key, y_key = grid.arg_keys
        
        x_vals = _get_val_list(full_df, x_key, grid.min_points_per_ax)
        y_vals = _get_val_list(full_df, y_key, grid.min_points_per_ax)

        if not x_vals or not x_vals:
            return

        x_vals = np.sort(x_vals)
        y_vals = np.sort(y_vals)
        shape = (len(x_vals), len(y_vals))

        for x_i, y_i in np.ndindex(shape):
            mask = (ax_df[x_key] == x_vals[x_i]) & (ax_df[y_key] == y_vals[y_i])

            if not mask.any():
                continue

            losses = ax_df[mask][self.key]

            if losses.isna().all():
                ax.plot(x_i, y_i, "x", ms=3, color="white", alpha=0.5)
            elif losses.isna().any():
                ax.plot(x_i, y_i, ".", ms=3, color="white", alpha=0.5)


PlotGrid(
    arg_keys=("config.T", "config.tau"),
    func_keys=(
        "metrics.acc_max_mean",
        "metrics.acc_ord_max_mean",
        # "metrics.epoch_time_mean",
        # "metrics.silent_neurons_final_mean",
    ),
    func_aggs={"*": "mean"},
    plots=[
        HeatmapPlot(),
        NanXPlot("metrics.loss_final_mean")
    ],
    fixed_values={
        "config.normalize_times": True,
        "config.w_scale": 0.5,
        "config.K": 700,
        "config.Nbatch": 1000,
        "config.Nhidden": 128,
    },
    fig_key="config.Nlayer",
    col_keys="config.gamma",
    indep_keys=indep_keys,
    key_format=key_format,
).show(trials_df)
# Out:
# Ignoring values of 'config.gamma' since they have less than 2 entries: [0.001, 0.1]
# Ignoring values of 'config.gamma' since they have less than 2 entries: [0.001, 0.1]

# %%
def get_variables(df, indep_keys):
    variables = {}
    for key in indep_keys:
        if len(vals := df[key].unique()) > 1:
            variables[key] = vals
    return variables

def expect_variables(df, indep_keys, expected_variables):
    variables = set(get_variables(df, indep_keys).keys())
    expect_variables = set(expected_variables)
    
    if variables != expect_variables:
        raise ValueError(f"Expected variables {expect_variables}, got {variables}")

def where_equals(df, values: dict):
    for key, value in values.items():
        df = df[df[key] == value]

    return df

# %%
# df = where_equals(trials_df, {
#     "config.normalize_times": True,
#     "config.w_scale": 0.5,
#     "config.Nlayer": 2,
#     "config.K": 700,
#     "config.Nhidden": 128,
#     "config.gamma": 0.1,
# })
# expect_variables(df, indep_keys, {"config.T", "config.tau"})
# # print_dict(get_variables(df, indep_keys), value_format=fmt_list)

# fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 6), sharex=True)

# def plot_tau_vs_T(ax, df, label):
#     T = df["config.T"]
#     tau = df["config.tau"]
#     log_T = np.log(T)
#     log_tau = np.log(tau)

#     line, = ax.plot(T, tau, 'o', label=label)

#     m, b = np.polyfit(log_T, log_tau, 1)

#     tau_fit = np.exp(m * log_T + b)

#     ax.plot(T, tau_fit, color=line.get_color(),
#             label=f"Fit: $\\tau = {np.exp(b):.3f} \\cdot T^{{{m:.3f}}}$")


# best_per_T = df.loc[df.groupby("config.T")["metrics.acc_max_mean"].idxmax()]
# plot_tau_vs_T(ax1, best_per_T, "with pseudospikes")
# ax2.plot(best_per_T["config.T"], best_per_T["metrics.acc_max_mean"], 'o--')

# best_ord_per_T = df.loc[df.groupby("config.T")["metrics.acc_ord_max_mean"].idxmax()]
# plot_tau_vs_T(ax1, best_ord_per_T, "without pseudospikes")
# ax2.plot(best_ord_per_T["config.T"], best_ord_per_T["metrics.acc_ord_max_mean"], 'o--')

# ax1.set_ylabel("$\\tau$ for best accuracy")
# ax1.set_yscale("log")
# ax1.legend()

# ax2.set_ylabel("Best accuracy")


# ax2.set_xlabel("$T$")
# ax2.set_xscale("log")

# for ax in (ax1, ax2):
#     ax.grid(which="major", alpha=0.5)
#     ax.grid(which="minor", alpha=0.2)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Best trials

# %%
from spikegd.utils.formatting import print_dict

def plot_training_curves(config_hash, metrics=["acc", "acc_ord"]):
    trial_epochs = epochs_df[epochs_df["config_hash"] == config_hash]
    
    epochs = np.arange(len(trial_epochs))
    
    fig, ax = plt.subplots()

    for metric in metrics:
        mean_arr = trial_epochs[f"{metric}_mean"]
        std_arr = trial_epochs[f"{metric}_std"]

        na_count = np.isnan(mean_arr).sum()
        if na_count > 0:
            print(f"Warning: {na_count} NaN values in {metric}_mean")

        ax.plot(epochs, mean_arr, label=metric)
        ax.fill_between(epochs, mean_arr - std_arr, mean_arr + std_arr, alpha=0.2)

    ax.set_xlabel("epoch")
    ax.set_ylabel(", ".join(metrics))
    ax.grid(alpha=0.5)
    ax.legend()

    plt.show()

def summarize_trial(trial_row):
    print("CONFIG")
    print_dict(
        {
            "- " + key.removeprefix("config."): value
            for key, value in trial_row.items()
            if key.startswith("config.")
        }
    )
    print("METRICS")

    def summarize_metric(mean_key):
        std_key = mean_key.replace("_mean", "_std")
        epoch_key = mean_key.replace("_mean", "_epoch")

        s = f"{trial_row[mean_key]:.4f}"

        if std_key in trial_row:
            s += f" ± {trial_row[std_key]:.4f}"

        if epoch_key in trial_row:
            s += f" at epoch {trial_row[epoch_key]:.0f}"

        return s

    print_dict(
        {
            "- " + key.removeprefix("metrics.").removesuffix("_mean"): summarize_metric(key)
            for key, value in trial_row.items()
            if key.startswith("metrics.") and key.endswith("_mean")
        },
        indent=32,
    )

best_trials = trials_df \
    .sort_values("metrics.acc_ord_max_mean", ascending=False, ignore_index=True) \
    .head(3)

for i, best_trial in best_trials.iterrows():
    print(f"===== BEST TRIAL {i} =====")
    # print(f"Max accuracy: {best_trial['metrics.acc_max_mean']:.4f} ± {best_trial['metrics.acc_max_std']:.4f} at epoch {best_trial['metrics.acc_max_epoch']}")
    summarize_trial(best_trial)
    plot_training_curves(best_trial["config_hash"])
# Out:
# ===== BEST TRIAL 0 =====
# CONFIG
# - device_count            1
# - seed                    0
# - I0                      1.25
# - eps                     1e-06
# - Nhidden                 128
# - Nlayer                  2
# - Nout                    20
# - w_scale                 0.5
# - K                       10000
# - dt                      0.001
# - gamma                   0.01
# - Nbatch                  1000
# - lr                      0.004
# - tau_lr                  100
# - beta1                   0.9
# - beta2                   0.999
# - p_flip                  0
# - Nepochs                 50
# - Ntrain                  None
# - Nin                     700
# - Nsamples                3
# - normalize_times         1
# - tau                     2
# - T                       2
# METRICS
# - acc_init                      0.0533 ± 0.0085
# - acc_final                     0.0449 ± 0.0012
# - acc_min                       0.0424 ± 0.0009 at epoch 19
# - acc_max                       0.1143 ± 0.0993 at epoch 1
# - acc_ord_init                  0.0458 ± 0.0016
# - acc_ord_final                 0.0449 ± 0.0012
# - acc_ord_min                   0.0424 ± 0.0009 at epoch 19
# - acc_ord_max                   0.0695 ± 0.0360 at epoch 1
# - activity_init                 0.2931 ± 0.0149
# - activity_final                0.0000 ± 0.0000
# - activity_min                  0.0000 ± 0.0000 at epoch 2
# - activity_max                  0.2931 ± 0.0149 at epoch 0
# - activity_first_init           0.2599 ± 0.0127
# - activity_first_final          0.0000 ± 0.0000
# - activity_first_min            0.0000 ± 0.0000 at epoch 2
# - activity_first_max            0.2599 ± 0.0127 at epoch 0
# - epoch_time                    7.8022 ± 0.0502
# - init_compile_time             0.0006 ± 0.0000
# - init_optim_time               0.0159 ± 0.0192
# - init_phi0_time                0.0270 ± 0.0373
# - init_time                     4.1648 ± 1.3098
# - init_weights_time             0.1691 ± 0.2376
# - loss_init                     3.0739 ± 0.0228
# - loss_final                    nan ± nan
# - loss_min                      3.0739 ± 0.0228 at epoch 0
# - loss_max                      3.0739 ± 0.0228 at epoch 0
# - loss_ord_init                 3.0129 ± 0.0000
# - loss_ord_final                3.0129 ± 0.0000
# - loss_ord_min                  3.0030 ± 0.0140 at epoch 1
# - loss_ord_max                  3.0129 ± 0.0000 at epoch 0
# - silent_neurons_init           0.1458 ± 0.0097
# - silent_neurons_final          1.0000 ± 0.0000
# - silent_neurons_min            0.1458 ± 0.0097 at epoch 0
# - silent_neurons_max            1.0000 ± 0.0000 at epoch 2
# - silent_neurons_first_init     0.1536 ± 0.0037
# - silent_neurons_first_final    1.0000 ± 0.0000
# - silent_neurons_first_min      0.1536 ± 0.0037 at epoch 0
# - silent_neurons_first_max      1.0000 ± 0.0000 at epoch 2
# - train_time                    390.1122 ± 2.5090
# ===== BEST TRIAL 1 =====
# CONFIG
# - device_count            1
# - seed                    0
# - I0                      1.25
# - eps                     1e-06
# - Nhidden                 128
# - Nlayer                  2
# - Nout                    20
# - w_scale                 0.5
# - K                       700
# - dt                      0.001
# - gamma                   0.01
# - Nbatch                  1000
# - lr                      0.004
# - tau_lr                  100
# - beta1                   0.9
# - beta2                   0.999
# - p_flip                  0
# - Nepochs                 50
# - Ntrain                  None
# - Nin                     700
# - Nsamples                3
# - normalize_times         1
# - tau                     0.25
# - T                       1
# METRICS
# - acc_init                      0.0490 ± 0.0029
# - acc_final                     0.0519 ± 0.0043
# - acc_min                       0.0464 ± 0.0009 at epoch 3
# - acc_max                       0.0551 ± 0.0081 at epoch 2
# - acc_ord_init                  0.0458 ± 0.0016
# - acc_ord_final                 0.0519 ± 0.0043
# - acc_ord_min                   0.0458 ± 0.0016 at epoch 0
# - acc_ord_max                   0.0551 ± 0.0081 at epoch 2
# - activity_init                 0.0012 ± 0.0001
# - activity_final                0.0000 ± 0.0000
# - activity_min                  0.0000 ± 0.0000 at epoch 1
# - activity_max                  0.0012 ± 0.0001 at epoch 0
# - activity_first_init           0.0000 ± 0.0000
# - activity_first_final          0.0000 ± 0.0000
# - activity_first_min            0.0000 ± 0.0000 at epoch 0
# - activity_first_max            0.0000 ± 0.0000 at epoch 0
# - epoch_time                    1.1272 ± 0.0193
# - init_compile_time             0.0006 ± 0.0000
# - init_optim_time               0.0174 ± 0.0215
# - init_phi0_time                0.0266 ± 0.0367
# - init_time                     3.5314 ± 1.3216
# - init_weights_time             0.1709 ± 0.2401
# - loss_init                     nan ± nan
# - loss_final                    2.9983 ± 0.0004
# - loss_min                      nan ± nan at epoch 0
# - loss_max                      nan ± nan at epoch 0
# - loss_ord_init                 3.0129 ± 0.0000
# - loss_ord_final                2.9983 ± 0.0004
# - loss_ord_min                  2.9983 ± 0.0004 at epoch 50
# - loss_ord_max                  3.0129 ± 0.0000 at epoch 0
# - silent_neurons_init           0.0729 ± 0.0097
# - silent_neurons_final          1.0000 ± 0.0000
# - silent_neurons_min            0.0729 ± 0.0097 at epoch 0
# - silent_neurons_max            1.0000 ± 0.0000 at epoch 1
# - silent_neurons_first_init     1.0000 ± 0.0000
# - silent_neurons_first_final    1.0000 ± 0.0000
# - silent_neurons_first_min      1.0000 ± 0.0000 at epoch 0
# - silent_neurons_first_max      1.0000 ± 0.0000 at epoch 0
# - train_time                    56.3584 ± 0.9660
# ===== BEST TRIAL 2 =====
# CONFIG
# - device_count            1
# - seed                    0
# - I0                      1.25
# - eps                     1e-06
# - Nhidden                 128
# - Nlayer                  2
# - Nout                    20
# - w_scale                 0.5
# - K                       10000
# - dt                      0.001
# - gamma                   0.01
# - Nbatch                  1000
# - lr                      0.004
# - tau_lr                  100
# - beta1                   0.9
# - beta2                   0.999
# - p_flip                  0
# - Nepochs                 50
# - Ntrain                  None
# - Nin                     700
# - Nsamples                3
# - normalize_times         1
# - tau                     2
# - T                       8
# METRICS
# - acc_init                      0.0492 ± 0.0156
# - acc_final                     0.0519 ± 0.0043
# - acc_min                       0.0463 ± 0.0012 at epoch 46
# - acc_max                       0.0548 ± 0.0024 at epoch 4
# - acc_ord_init                  0.0492 ± 0.0156
# - acc_ord_final                 0.0519 ± 0.0043
# - acc_ord_min                   0.0463 ± 0.0012 at epoch 46
# - acc_ord_max                   0.0548 ± 0.0024 at epoch 4
# - activity_init                 0.8646 ± 0.0300
# - activity_final                0.0000 ± 0.0000
# - activity_min                  0.0000 ± 0.0000 at epoch 1
# - activity_max                  0.8646 ± 0.0300 at epoch 0
# - activity_first_init           0.3063 ± 0.0095
# - activity_first_final          0.0000 ± 0.0000
# - activity_first_min            0.0000 ± 0.0000 at epoch 1
# - activity_first_max            0.3063 ± 0.0095 at epoch 0
# - epoch_time                    7.7830 ± 0.0353
# - init_compile_time             0.0005 ± 0.0000
# - init_optim_time               0.0149 ± 0.0178
# - init_phi0_time                0.0230 ± 0.0317
# - init_time                     4.1021 ± 1.2624
# - init_weights_time             0.1618 ± 0.2273
# - loss_init                     nan ± nan
# - loss_final                    2.9999 ± 0.0004
# - loss_min                      nan ± nan at epoch 0
# - loss_max                      nan ± nan at epoch 0
# - loss_ord_init                 3.0087 ± 0.0123
# - loss_ord_final                2.9999 ± 0.0004
# - loss_ord_min                  2.9999 ± 0.0004 at epoch 50
# - loss_ord_max                  3.0087 ± 0.0123 at epoch 0
# - silent_neurons_init           0.0000 ± 0.0000
# - silent_neurons_final          1.0000 ± 0.0000
# - silent_neurons_min            0.0000 ± 0.0000 at epoch 0
# - silent_neurons_max            1.0000 ± 0.0000 at epoch 1
# - silent_neurons_first_init     0.0078 ± 0.0000
# - silent_neurons_first_final    1.0000 ± 0.0000
# - silent_neurons_first_min      0.0078 ± 0.0000 at epoch 0
# - silent_neurons_first_max      1.0000 ± 0.0000 at epoch 1
# - train_time                    389.1508 ± 1.7641
